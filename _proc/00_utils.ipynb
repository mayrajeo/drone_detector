# %% [raw]
# ---
# description: Common, useful functions to use in several places.
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Utilities

# %%
#|output: asis
#| echo: false
show_doc(rangeof)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/utils.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### rangeof
#
# >      rangeof (iterable)
#
# Equivalent for range(len(iterable))

# %%
#|output: asis
#| echo: false
show_doc(fix_multipolys)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/utils.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### fix_multipolys
#
# >      fix_multipolys (multipoly:shapely.geometry.multipolygon.MultiPolygon)
#
# Convert MultiPolygon to a single Polygon.
# The resulting Polygon has the exterior boundaries of the largest geometry of the MultiPolygon

# %% [markdown]
# ## Math formulae (for fallen deadwood volume estimation)

# %%
#|output: asis
#| echo: false
show_doc(cut_cone_v)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/utils.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### cut_cone_v
#
# >      cut_cone_v (r_1:float, r_2:float, h:float)
#
# V = (h(A + sqrt(A*A') + A))/3

# %%
#|output: asis
#| echo: false
show_doc(cone_v)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/utils.py#L28){target="_blank" style="float:right; font-size:smaller"}
#
# ### cone_v
#
# >      cone_v (r:float, h:float)
#
# V = (Ah)/3
