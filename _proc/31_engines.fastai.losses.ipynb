# %% [raw]
# ---
# output-file: engines.fastai.losses.html
# title: Custom losses for segmentation and object detection
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Lovász-losses
#
# > From [https://github.com/bermanmaxim/LovaszSoftmax](https://github.com/bermanmaxim/LovaszSoftmax)

# %%
#|output: asis
#| echo: false
show_doc(xloss)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L233){target="_blank" style="float:right; font-size:smaller"}
#
# ### xloss
#
# >      xloss (logits, labels, ignore=None)
#
# Cross entropy loss

# %%
#|output: asis
#| echo: false
show_doc(flatten_probas)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L215){target="_blank" style="float:right; font-size:smaller"}
#
# ### flatten_probas
#
# >      flatten_probas (probas, labels, ignore=None)
#
# Flattens predictions in the batch

# %%
#|output: asis
#| echo: false
show_doc(lovasz_softmax_flat)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L184){target="_blank" style="float:right; font-size:smaller"}
#
# ### lovasz_softmax_flat
#
# >      lovasz_softmax_flat (probas, labels, classes='present')
#
# Multi-class Lovasz-Softmax loss
#   probas: [P, C] Variable, class probabilities at each prediction (between 0 and 1)
#   labels: [P] Tensor, ground truth labels (between 0 and C - 1)
#   classes: 'all' for all, 'present' for classes present in labels, or a list of classes to average.

# %%
#|output: asis
#| echo: false
show_doc(lovasz_softmax)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L166){target="_blank" style="float:right; font-size:smaller"}
#
# ### lovasz_softmax
#
# >      lovasz_softmax (probas, labels, classes='present', per_image=False,
# >                      ignore=None)
#
# Multi-class Lovasz-Softmax loss
#   probas: [B, C, H, W] Variable, class probabilities at each prediction (between 0 and 1).
#           Interpreted as binary (sigmoid) output with outputs of size [B, H, W].
#   labels: [B, H, W] Tensor, ground truth labels (between 0 and C - 1)
#   classes: 'all' for all, 'present' for classes present in labels, or a list of classes to average.
#   per_image: compute the loss per image instead of per batch
#   ignore: void class labels

# %%
#|output: asis
#| echo: false
show_doc(flatten_binary_scores)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L152){target="_blank" style="float:right; font-size:smaller"}
#
# ### flatten_binary_scores
#
# >      flatten_binary_scores (scores, labels, ignore=None)
#
# Flattens predictions in the batch (binary case)
# Remove labels equal to 'ignore'

# %%
#|output: asis
#| echo: false
show_doc(lovasz_hinge_flat)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L132){target="_blank" style="float:right; font-size:smaller"}
#
# ### lovasz_hinge_flat
#
# >      lovasz_hinge_flat (logits, labels)
#
# Binary Lovasz hinge loss
#   logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
#   labels: [P] Tensor, binary ground truth labels (0 or 1)
#   ignore: label to ignore

# %%
#|output: asis
#| echo: false
show_doc(lovasz_hinge)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L116){target="_blank" style="float:right; font-size:smaller"}
#
# ### lovasz_hinge
#
# >      lovasz_hinge (logits, labels, per_image=True, ignore=None)
#
# Binary Lovasz hinge loss
#   logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
#   labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
#   per_image: compute the loss per image instead of per batch
#   ignore: void class id

# %%
#|output: asis
#| echo: false
show_doc(mean)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L96){target="_blank" style="float:right; font-size:smaller"}
#
# ### mean
#
# >      mean (l, ignore_nan=False, empty=0)
#
# nanmean compatible with generators.

# %%
#|output: asis
#| echo: false
show_doc(isnan)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L92){target="_blank" style="float:right; font-size:smaller"}
#
# ### isnan
#
# >      isnan (x)

# %%
#|output: asis
#| echo: false
show_doc(iou)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L70){target="_blank" style="float:right; font-size:smaller"}
#
# ### iou
#
# >      iou (preds, labels, C, EMPTY=1.0, ignore=None, per_image=False)
#
# Array of IoU for each (non ignored) class

# %%
#|output: asis
#| echo: false
show_doc(iou_binary)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### iou_binary
#
# >      iou_binary (preds, labels, EMPTY=1.0, ignore=None, per_image=True)
#
# IoU for foreground class
# binary: 1 foreground, 0 background

# %%
#|output: asis
#| echo: false
show_doc(lovasz_grad)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### lovasz_grad
#
# >      lovasz_grad (gt_sorted)
#
# Computes gradient of the Lovasz extension w.r.t sorted errors
# See Alg. 1 in paper

# %%
#|output: asis
#| echo: false
show_doc(LovaszHingeLoss)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L249){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszHingeLoss
#
# >      LovaszHingeLoss (ignore=None)
#
# Lovasz-Hinge loss from https://arxiv.org/abs/1705.08790, with per_image=True
#
# Todo
#
# Binary Lovasz hinge loss
#   logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
#   labels: [P] Tensor, binary ground truth labels (0 or 1)
#   ignore: label to ignore

# %%
#|output: asis
#| echo: false
show_doc(LovaszHingeLossFlat)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L240){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszHingeLossFlat
#
# >      LovaszHingeLossFlat (*args, axis=-1, ignore=None, **kwargs)
#
# Same as `LovaszHingeLoss` but flattens input and target

# %%
lov_hinge = LovaszHingeLossFlat()
outp = torch.randn(4,1,128,128)
target = torch.randint(0, 2, (4,1,128,128))

# %%
lov_hinge(outp, target)
# Out:
# tensor(1.4331)

# %%
lovasz_hinge(outp, target)
# Out:
# tensor(1.4331)

# %%
#|output: asis
#| echo: false
show_doc(LovaszSigmoidLoss)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L293){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszSigmoidLoss
#
# >      LovaszSigmoidLoss (ignore=None)
#
# Lovasz-Sigmoid loss from https://arxiv.org/abs/1705.08790, with per_image=False
#
# Todo
#
#   probas: [P, C] Variable, logits at each prediction (between -\infty and +\infty)
#   labels: [P] Tensor, binary ground truth labels (0 or 1)
#   ignore: label to ignore

# %%
#|output: asis
#| echo: false
show_doc(LovaszSigmoidLossFlat)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L285){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszSigmoidLossFlat
#
# >      LovaszSigmoidLossFlat (*args, axis=-1, ignore=None, **kwargs)
#
# Same as `LovaszSigmoidLoss` but flattens input and target

# %%
lov_sigmoid = LovaszSigmoidLossFlat()

# %%
lov_sigmoid(outp, target)
# Out:
# tensor(0.5823)

# %%
lovasz_softmax(torch.sigmoid(outp), target, classes=[1])
# Out:
# tensor(0.5823)

# %%
#|output: asis
#| echo: false
show_doc(LovaszSoftmaxLoss)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L338){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszSoftmaxLoss
#
# >      LovaszSoftmaxLoss (classes='present', ignore=None)
#
# Lovasz-Sigmoid loss from https://arxiv.org/abs/1705.08790, with per_image=False

# %%
#|output: asis
#| echo: false
show_doc(LovaszSoftmaxLossFlat)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L328){target="_blank" style="float:right; font-size:smaller"}
#
# ### LovaszSoftmaxLossFlat
#
# >      LovaszSoftmaxLossFlat (*args, axis=1, classes='present', ignore=None,
# >                             **kwargs)
#
# Same as `LovaszSigmoidLoss` but flattens input and target

# %%
lov_softmax = LovaszSoftmaxLossFlat()
outp_multi = torch.randn(4,3,128,128)
target_multi = torch.randint(0, 3, (4,1,128,128))
lov_softmax(outp_multi, target_multi)
# Out:
# tensor(0.7045)

# %%
lovasz_softmax(F.softmax(outp_multi, dim=1), target_multi)
# Out:
# tensor(0.7045)

# %%
lov_softmax_subset = LovaszSoftmaxLossFlat(classes=[1,2])
lov_softmax_subset(outp_multi, target_multi)
# Out:
# tensor(0.7039)

# %%
lovasz_softmax(F.softmax(outp_multi, dim=1), target_multi, classes=[1,2])
# Out:
# tensor(0.7039)

# %%
#|output: asis
#| echo: false
show_doc(FocalDice)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/losses.py#L379){target="_blank" style="float:right; font-size:smaller"}
#
# ### FocalDice
#
# >      FocalDice (axis=1, smooth=1.0, alpha=1.0)
#
# Combines Focal loss with dice loss
