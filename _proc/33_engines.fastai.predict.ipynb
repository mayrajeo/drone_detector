# %% [raw]
# ---
# output-file: engines.fastai.predict.html
# title: CLI for inference using fastai models
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Remove all transformations so [`predict_segmentation`](https://mayrajeo.github.io/drone_detector/engines.fastai.predict.html#predict_segmentation) works with any image size and returns same sized output than input.

# %%
#|output: asis
#| echo: false
show_doc(DataLoader.set_base_transforms)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/predict.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### DataLoader.set_base_transforms
#
# >      DataLoader.set_base_transforms ()
#
# Removes all transforms with a `size` parameter

# %%
#|output: asis
#| echo: false
show_doc(Pipeline.remove)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/predict.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline.remove
#
# >      Pipeline.remove (t)
#
# Remove an instance of `t` from `self` if present

# %%
#|output: asis
#| echo: false
show_doc(predict_segmentation)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/predict.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### predict_segmentation
#
# >      predict_segmentation (path_to_model:str, path_to_image:str, outfile:str,
# >                            processing_dir:str='temp', tile_size:int=400,
# >                            tile_overlap:int=100, use_tta:bool=False)
#
# Segment image into land cover classes with a pretrained models
# TODO save also information about label and class
# TODO add test-time augmentations

# %%
#|output: asis
#| echo: false
show_doc(predict_segmentation_fastai)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/fastai/predict.py#L135){target="_blank" style="float:right; font-size:smaller"}
#
# ### predict_segmentation_fastai
#
# >      predict_segmentation_fastai (path_to_model:str, path_to_image:str,
# >                                   outfile:str, processing_dir:str='temp',
# >                                   tile_size:int=400, tile_overlap:int=100,
# >                                   use_tta:bool=False)
#
# CLI for semantic segmentation with fastai
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | path_to_model | str |  | Path to pretrained model file |
# | path_to_image | str |  | Path to image to annotate |
# | outfile | str |  | Path and filename for output raster |
# | processing_dir | str | temp | Directory to save the intermediate tiles. Deleted after use |
# ...
