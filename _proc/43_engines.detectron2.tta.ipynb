# %% [raw]
# ---
# description: Implement both HFlip and VFlip as TTA transforms, add support for RotatedBoxes
# output-file: engines.detectron2.tta.html
# title: Custom TTA modifications for detectron2
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(DatasetMapperTTAFlip)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/detectron2/tta.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### DatasetMapperTTAFlip
#
# >      DatasetMapperTTAFlip (min_sizes:List[int], max_size:int, flip:bool)
#
# Implement test-time augmentation for detection data. Modified to implement both horizontal and vertical flip
# It is a callable which takes a dataset dict from a detection dataset,
# and returns a list of dataset dicts where the images
# are augmented from the input image by the transformations defined in the config.
# This is used for test-time augmentation.

# %%
#|output: asis
#| echo: false
show_doc(TTAPredictor)
# Out:
# ---
#
# [source](https://github.com/mayrajeo/drone_detector/tree/master/blob/master/drone_detector/engines/detectron2/tta.py#L184){target="_blank" style="float:right; font-size:smaller"}
#
# ### TTAPredictor
#
# >      TTAPredictor (cfg)
#
# DefaultPredictor that implements TTA
